# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulbhoyar1995/IU-AI/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Add your code here for this repository.

# %%
# !curl ipinfo.io
# Out:
# {
#   "ip": "35.226.193.221",
#   "hostname": "221.193.226.35.bc.googleusercontent.com",
#   "city": "Council Bluffs",
#   "region": "Iowa",
#   "country": "US",
#   "loc": "41.2619,-95.8608",
#   "org": "AS396982 Google LLC",
#   "postal": "51502",
#   "timezone": "America/Chicago",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
# Out:
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7a3937dc8700>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 111, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 87, in _retrieve_info
#     info = _metadata.get_service_account_info(
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 234, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 182, in get
#     raise exceptions.TransportError(
# ...
